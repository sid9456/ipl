# %%
import numpy as np
import pandas as pd

# %%
deliveries=pd.read_csv('~/Downloads/deliveries.csv')

# %%
matches=pd.read_csv('~/Downloads/matches.csv')

# %%
deliveries.head()
# Out:
#    match_id  inning         batting_team                 bowling_team  over  \
# 0         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 1         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 2         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 3         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
# 4         1       1  Sunrisers Hyderabad  Royal Challengers Bangalore     1
#
#    ball    batsman non_striker    bowler  is_super_over  ...  bye_runs  \
# 0     1  DA Warner    S Dhawan  TS Mills              0  ...         0
# 1     2  DA Warner    S Dhawan  TS Mills              0  ...         0
# 2     3  DA Warner    S Dhawan  TS Mills              0  ...         0
# 3     4  DA Warner    S Dhawan  TS Mills              0  ...         0
# 4     5  DA Warner    S Dhawan  TS Mills              0  ...         0
#
#    legbye_runs  noball_runs  penalty_runs  batsman_runs  extra_runs  \
# ...

# %%
matches.head()
# Out:
#    id    Season       city        date                        team1  \
# 0   1  IPL-2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  06-04-2017               Mumbai Indians
# 2   3  IPL-2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4  IPL-2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5  IPL-2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
# we need to have batting team,bowling team,city, runs_left,balls_left,wickets_left,total_runs crr,rrr, result

# %%
total_score_df=deliveries.groupby(['match_id','inning']).sum()['total_runs'].reset_index()

# %%
total_score_df=total_score_df[(total_score_df['inning']==1)]

# %%
total_score_df=total_score_df.reset_index()

# %%
total_score_df=total_score_df.drop(['index'],axis=1)

# %%
df=pd.concat([matches,total_score_df],axis=1)

# %%
df=df.drop(['inning'],axis=1)

# %%
df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Daredevils', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Deccan Chargers',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Rising Pune Supergiants',
#        'Delhi Capitals'], dtype=object)

# %%
df['team1']=df['team1'].str.replace('Delhi Daredevils','Delhi Capitals')
df['team2']=df['team2'].str.replace('Delhi Daredevils','Delhi Capitals')

df['team1']=df['team1'].str.replace('Deccan Chargers','Sunrisers Hyderabad')
df['team2']=df['team2'].str.replace('Deccan Chargers','Sunrisers Hyderabad')

# %%
df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Mumbai Indians', 'Gujarat Lions',
#        'Rising Pune Supergiant', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
#        'Chennai Super Kings', 'Rajasthan Royals', 'Kochi Tuskers Kerala',
#        'Pune Warriors', 'Rising Pune Supergiants'], dtype=object)

# %%
teams=['Sunrisers Hyderabad', 'Mumbai Indians',
        'Royal Challengers Bangalore',
       'Kolkata Knight Riders', 'Delhi Capitals', 'Kings XI Punjab',
       'Chennai Super Kings', 'Rajasthan Royals',
       ]

# %%
df=df[df['team1'].isin(teams)]
df=df[df['team2'].isin(teams)]

# %%
df['team1'].unique()
# Out:
# array(['Sunrisers Hyderabad', 'Royal Challengers Bangalore',
#        'Kolkata Knight Riders', 'Kings XI Punjab', 'Delhi Capitals',
#        'Mumbai Indians', 'Chennai Super Kings', 'Rajasthan Royals'],
#       dtype=object)

# %%
df.shape
# Out:
# (641, 20)

# %%
df['dl_applied'].value_counts()
# Out:
# 0    626
# 1     15
# Name: dl_applied, dtype: int64

# %%
df=df[(df['dl_applied']==0)].reset_index()

# %%
df=df.drop(['index'],axis=1)

# %%
match_df=df[['match_id','city','winner','total_runs']]

# %%
dely_df=match_df.merge(deliveries,on='match_id')

# %%
deliveries.shape
# Out:
# (179078, 21)

# %%
dely_df=dely_df[(dely_df['inning']==2)]

# %%
dely_df.shape
# Out:
# (72413, 24)

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... bye_runs legbye_runs  noball_runs  penalty_runs  \
# 125       CH Gayle  ...        0           0            0             0
# ...

# %%
dely_df['current_score']=dely_df.groupby('match_id').cumsum()['total_runs_y']
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/2429235509.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['current_score']=dely_df.groupby('match_id').cumsum()['total_runs_y']

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... legbye_runs noball_runs  penalty_runs  batsman_runs  \
# 125       CH Gayle  ...           0           0             0             1
# ...

# %%
dely_df['runs_left']=dely_df['total_runs_x']-dely_df['current_score']
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/3880332021.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['runs_left']=dely_df['total_runs_x']-dely_df['current_score']

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... noball_runs penalty_runs  batsman_runs  extra_runs  \
# 125       CH Gayle  ...           0            0             1           0
# ...

# %%
dely_df['balls_left']=126-(dely_df['over']*6 + dely_df['ball'])
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/358017863.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['balls_left']=126-(dely_df['over']*6 + dely_df['ball'])

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... penalty_runs batsman_runs  extra_runs  total_runs_y  \
# 125       CH Gayle  ...            0            1           0             1
# ...

# %%
dely_df['player_dismissed']=dely_df['player_dismissed'].fillna('0')
dely_df['player_dismissed']=dely_df['player_dismissed'].apply(lambda x:x if x =='0' else 1)
dely_df['player_dismissed']=dely_df['player_dismissed'].astype('int')
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/2752584502.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['player_dismissed']=dely_df['player_dismissed'].fillna('0')
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/2752584502.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['player_dismissed']=dely_df['player_dismissed'].apply(lambda x:x if x =='0' else 1)
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/2752584502.py:3: SettingWithCopyWarning:
# ...

# %%
wickets=dely_df.groupby('match_id').cumsum()['player_dismissed'].values
dely_df['wickets']=10-wickets
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/872932973.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['wickets']=10-wickets

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... batsman_runs extra_runs  total_runs_y  \
# 125       CH Gayle  ...            1          0             1
# ...

# %%
dely_df['crr']=dely_df['current_score']*6/(120-dely_df['balls_left'])
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/1132070028.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['crr']=dely_df['current_score']*6/(120-dely_df['balls_left'])

# %%
dely_df['rrr']=(dely_df['runs_left']*6)/dely_df['balls_left']
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/3814127558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['rrr']=(dely_df['runs_left']*6)/dely_df['balls_left']

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... total_runs_y player_dismissed  dismissal_kind  \
# 125       CH Gayle  ...            1                0             NaN
# ...

# %%
def result(row):
    return 1 if row['batting_team'] == row['winner'] else 0

# %%
dely_df['result']=dely_df.apply(result,axis=1)
# Out:
# C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_6988/3567376287.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dely_df['result']=dely_df.apply(result,axis=1)

# %%
dely_df.head()
# Out:
#      match_id       city               winner  total_runs_x  inning  \
# 125         1  Hyderabad  Sunrisers Hyderabad           207       2
# 126         1  Hyderabad  Sunrisers Hyderabad           207       2
# 127         1  Hyderabad  Sunrisers Hyderabad           207       2
# 128         1  Hyderabad  Sunrisers Hyderabad           207       2
# 129         1  Hyderabad  Sunrisers Hyderabad           207       2
#
#                     batting_team         bowling_team  over  ball  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad     1     1
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad     1     2
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad     1     3
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad     1     4
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad     1     5
#
#            batsman  ... player_dismissed dismissal_kind  fielder  \
# 125       CH Gayle  ...                0            NaN      NaN
# ...

# %%
final_df=dely_df[['batting_team','bowling_team','city','runs_left','balls_left','wickets','total_runs_x','crr','rrr','result']]

# %%
final_df.head()
# Out:
#                     batting_team         bowling_team       city  runs_left  \
# 125  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 126  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 127  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        206
# 128  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        204
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        200
#
#      balls_left  wickets  total_runs_x  crr        rrr  result
# 125         119       10           207  6.0  10.386555       0
# 126         118       10           207  3.0  10.474576       0
# 127         117       10           207  2.0  10.564103       0
# 128         116       10           207  4.5  10.551724       0
# 129         115       10           207  8.4  10.434783       0

# %%
final_df=final_df.sample(final_df.shape[0])
final_df.head()
# Out:
#                  batting_team         bowling_team        city  runs_left  \
# 136104       Rajasthan Royals      Kings XI Punjab      Jaipur        168
# 133933         Mumbai Indians     Delhi Daredevils       Delhi        131
# 49378         Kings XI Punjab  Chennai Super Kings  Chandigarh        172
# 39640   Kolkata Knight Riders     Delhi Daredevils       Delhi         43
# 52089         Deccan Chargers       Mumbai Indians   Hyderabad         73
#
#         balls_left  wickets  total_runs_x        crr        rrr  result
# 136104          97       10           200   8.347826  10.391753       0
# 133933          87        9           186  10.000000   9.034483       0
# 49378          106       10           188   6.857143   9.735849       1
# 39640            6        3           177   7.052632  43.000000       0
# 52089           34        5           172   6.906977  12.882353       0

# %%
final_df.sample()
# Out:
#                     batting_team         bowling_team       city  runs_left  \
# 129  Royal Challengers Bangalore  Sunrisers Hyderabad  Hyderabad        200
#
#      balls_left  wickets  total_runs_x  crr        rrr  result
# 129         115       10           207  8.4  10.434783       0

# %%
final_df.dropna(inplace=True)

# %%
final_df=final_df[(final_df['balls_left']!= 0 )]

# %%
from sklearn.model_selection import train_test_split

# %%
X=final_df.drop(['result'],axis=1)
y=final_df['result']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
trf=ColumnTransformer([('trf',OneHotEncoder(sparse=False,drop='first'),['batting_team','bowling_team','city'])]
                       ,remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe=Pipeline(steps=[('step1',trf),('step2',LogisticRegression(solver='liblinear'))])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred=pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.8097273810358119

# %%
teams
# Out:
# ['Sunrisers Hyderabad',
#  'Mumbai Indians',
#  'Royal Challengers Bangalore',
#  'Kolkata Knight Riders',
#  'Delhi Capitals',
#  'Kings XI Punjab',
#  'Chennai Super Kings',
#  'Rajasthan Royals']

# %%
dely_df['city'].unique()
# Out:
# array(['Hyderabad', 'Bangalore', 'Mumbai', 'Indore', 'Kolkata', 'Delhi',
#        'Chandigarh', 'Jaipur', 'Chennai', 'Cape Town', 'Port Elizabeth',
#        'Durban', 'Centurion', 'East London', 'Johannesburg', 'Kimberley',
#        'Bloemfontein', 'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala',
#        'Visakhapatnam', 'Pune', 'Raipur', 'Ranchi', 'Abu Dhabi',
#        'Sharjah', nan, 'Mohali', 'Bengaluru'], dtype=object)

# %%
import pickle 
pickle.dump(pipe,open('pipe.pkl','wb'))

# %%
m pip show scikit-learn
# Out:
#   File "C:\Users\SIDDHA~1\AppData\Local\Temp/ipykernel_11992/552257583.py", line 1
#     m pip show scikit-learn
#       ^
# SyntaxError: invalid syntax

# %%
import sklearn; sklearn.show_versions()
# Out:
# System:
#     python: 3.8.12 (default, Oct 12 2021, 03:01:40) [MSC v.1916 64 bit (AMD64)]
# executable: C:\Users\siddharth\anaconda3\python.exe
#    machine: Windows-10-10.0.19043-SP0
#
# Python dependencies:
#       sklearn: 1.1.2
#           pip: 21.2.2
#    setuptools: 58.0.4
#         numpy: 1.20.3
#         scipy: 1.7.3
#        Cython: 0.29.25
#        pandas: 1.3.5
#    matplotlib: 3.5.0
#        joblib: 1.1.0
# threadpoolctl: 2.2.0
#
# Built with OpenMP: True
#
# threadpoolctl info:
#        filepath: C:\Users\siddharth\anaconda3\Lib\site-packages\sklearn\.libs\vcomp140.dll
#          prefix: vcomp
#        user_api: openmp
#    internal_api: openmp
#         version: None
#     num_threads: 4
#
#        filepath: C:\Users\siddharth\anaconda3\Library\bin\mkl_rt.1.dll
#          prefix: mkl_rt
#        user_api: blas
#    internal_api: mkl
#         version: 2021.4-Product
#     num_threads: 2
# threading_layer: intel
#
# ...

# %%
pip install scikit-learn==1.1.1
# Out:
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Uninstalling scikit-learn-1.1.2:
#       Successfully uninstalled scikit-learn-1.1.2
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\siddharth\\anaconda3\\Lib\\site-packages\\~-learn\\.libs\\vcomp140.dll'
# Consider using the `--user` option or check the permissions.
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\siddharth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\siddharth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\siddharth\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\siddharth\anaconda3\lib\site-packages)
# ...
# WARNING: Ignoring invalid distribution -cikit-learn (c:\users\siddharth\anaconda3\lib\site-packages)
# ...

# %%
pip install scikit-learn
# Out:
# ...
#
# ...
#   Using cached scikit-learn-0.18.2.tar.gz (9.2 MB)
# ...
#   Running setup.py clean for scikit-learn
# Failed to build scikit-learn
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.2
#     Uninstalling scikit-learn-1.1.2:
#       Successfully uninstalled scikit-learn-1.1.2
#     Running setup.py install for scikit-learn: started
#     Running setup.py install for scikit-learn: finished with status 'error'
#   Rolling back uninstall of scikit-learn
#   Moving to c:\users\siddharth\anaconda3\lib\site-packages\scikit_learn-1.1.2.dist-info\
#    from C:\Users\siddharth\anaconda3\Lib\site-packages\~cikit_learn-1.1.2.dist-info
#   Moving to c:\users\siddharth\anaconda3\lib\site-packages\sklearn\
#    from C:\Users\siddharth\anaconda3\Lib\site-packages\~-learn
#   ERROR: Command errored out with exit status 1:
# ...
